# %% [markdown]
# Importing the list posts from RSSArticles_1.py

# %%
# 1) Import posts from RssArticles_1
from RssArticles_1 import posts
import datetime
from datetime import datetime
import pandas as pd
import feedparser

# %%
# combined_data = [
#     f"{post.get('title', '')} - {post.get('summary', '')}".strip(" - ")  # Behåll titeln även om summeringen saknas
#     for post in posts
# ]
# print (posts)
# df = pd.DataFrame(combined_data, columns=['Combined']) #konvertera till en pandas dataframe med endast en kolumnt

# print (df)

# %%
def gettingNecessaryList():
    """
    This function loops through 'posts' and extracts:
      title, summary, link, published
    Then stores them in a dictionary, finally returns a list of these dictionaries.
    """
    # Pseudo code:
    #  1. Initialize an empty list (allitems)
    #  2. Loop through each 'post' in 'posts'
    #  3. Create a temp dict for each 'post'
    #  4. Extract needed keys; if missing, set to empty string
    #  5. Append the dict to the list
    #  6. Return allitems
    
    allitems = []
    
    #TODO: Replace with your actual code, e.g.:
    for x in posts:
        tempdict = {}
        tempdict["title"] = x.get("title", "")
        tempdict["summary"] = x.get("summary", "")
        tempdict["link"] = x.get("link", "")
        tempdict["published"] = x.get("published", "")
        allitems.append(tempdict)
    
    return allitems

# %%
#Store the list
AllItemsX = gettingNecessaryList()
#validate
print (AllItemsX)
# Out:
# [{'title': 'Musk: Trump med på att skrota USAID', 'summary': 'Donald Trumps nära rådgivare Elon Musk vill lägga ner biståndsmyndigheten USAID och säger att presidenten är med på beslutet. ”USAID är en kriminell organisation”, dundrar han på sin plattform X där USAID har portats.', 'link': 'https://www.dn.se/varlden/musk-trump-med-pa-att-skrota-usaid/', 'published': 'Mon, 3 Feb 2025 09:12:17 +0100'}, {'title': 'Bred nedgång på Stockholmsbörsen', 'summary': 'Stockholmsbörsen faller brett i den inledande handeln i spåren av president Donald Trumps tullhot. OMXS-index är ned 2,5 procent.', 'link': 'https://www.dn.se/ekonomi/bred-nedgang-pa-stockholmsborsen-13/', 'published': 'Mon, 3 Feb 2025 09:09:15 +0100'}, {'title': 'Med uppdrag att stoppa bidragsfusket', 'summary': 'Nya Utbetalningsmyndigheten har på ett år hittat över 300 misstänkta bidragsbrott genom att samköra myndigheternas system, fall som inte hade upptäckts med tidigare metoder. Nästa steg är att ta fram en modell för att upptäcka fusk kopplat till utlandet, berättar generaldirektören Per Eleblad.', 'link': 'https://www.dn.se/ekonomi/med-uppdrag-att-stoppa-bidragsfusket/', 'published': 'Mon, 3 Feb 2025 08:57:07 +0100'}, {'title': 'Europa oroar sig över Trump 2.0 – resten av världen optimistiska', 'summary': 'BRYSSEL. I Europa betraktas Donald Trump som en fara. Men i stora delar av övriga världen tror man i stället att maktskiftet i USA kan få stopp på kriget i Ukraina, visar en global opinionsmätning.', 'link': 'https://www.dn.se/varlden/europa-oroar-sig-over-trump-2-0-resten-av-varlden-optimistiska/', 'published': 'Mon, 3 Feb 2025 08:46:44 +0100'}, {'title': 'Trump rensar hemsidor på ”mångfald” och ”inkludering”', 'summary': 'Efter president Donald Trumps direktiv rensas amerikanska myndigheters webbplatser på ord som ”mångfald” och ”inkludering”. Uttryck som ”gravida människor” ersätts med ”gravida kvinnor”, rapporterar Washington Post.', 'link': 'https://www.dn.se/varlden/trump-rensar-hemsidor-pa-mangfald-och-inkludering/', 'published': 'Mon, 3 Feb 2025 08:46:08 +0100'}, {'title': 'Kalena: Det kanske inte alls var North Dakota du såg', 'summary': 'Äntligen når Kalena sin 49:e delstat. Men har du sett North Dakota på film eller tv är det stor chans att du såg något helt annat.', 'link': 'https://www.dn.se/kultur/kalena-det-kanske-inte-alls-var-north-dakota-du-sag/', 'published': 'Mon, 3 Feb 2025 07:36:13 +0100'}, {'title': 'Oväntad coach i historiska matcher: ”Känns speciellt”', 'summary': 'När det för första gången ska spelas hockeymatcher i nyrenoverade Avicii arena är det inte ordinarie förbundskapten Sam Hallam som basar över laget. I stället kommer Tre Kronor under veckans landslagsturnering ledas av vikarien Magnus Hävelid.', 'link': 'https://www.dn.se/sport/ovantad-coach-i-historiska-matcher-kanns-speciellt/', 'published': 'Mon, 3 Feb 2025 07:18:49 +0100'}, {'title': 'Lamar prisades för diss – Beyoncés album bäst', 'summary': 'Världsstjärnan Kendrick Lamar prisades två gånger om för sin Drake-diss ”Not like Us”, som tog hem både årets låt och årets inspelning. Årets album blev Beyoncés ”Cowboy Carter” och årets artist Chappell Roan.', 'link': 'https://www.dn.se/kultur/lamar-prisades-for-diss-beyonces-album-bast/', 'published': 'Mon, 3 Feb 2025 06:55:34 +0100'}, {'title': 'Ledare: ”Hårda tag” räcker inte mot hedersvåldet', 'summary': 'Nu är det inte längre tabu att tala om hedersvåld. Men samhället är fortfarande för dåligt på att stoppa det.', 'link': 'https://www.dn.se/ledare/harda-tag-racker-inte-mot-hedersvaldet/', 'published': 'Mon, 3 Feb 2025 06:03:55 +0100'}, {'title': 'Var finns största glaciären?', 'summary': 'Testa dina kunskaper om iskalla ting.', 'link': 'https://www.dn.se/quiz/djur-och-natur/is-och-glaciarer/', 'published': 'Mon, 3 Feb 2025 06:00:00 +0100'}, {'title': 'Rättsläkare: Större risk att utomstående skadas', 'summary': 'När gängen använder militära kulor ökar risken för att utomstående drabbas av skjutvapenvåldet, enligt rättsläkaren Lyd ...

# %%
from datetime import datetime

def ThefinalList():
    """
    This function converts AllItemsX into a final 2D list (or list of lists),
    while ensuring that 'published' is properly formatted (YYYY-MM-DD HH:MM:SS).
    """
    finalList = []
    
    # List of possible date formats to try
    possible_formats = [
        "%Y-%m-%d %H:%M:%S",     # e.g., 2025-02-03 15:30:00
        "%Y-%m-%dT%H:%M:%SZ",    # e.g., 2025-02-03T15:30:00Z (common in JSON APIs)
        "%a, %d %b %Y %H:%M:%S %z",  # e.g., Tue, 03 Feb 2025 15:30:00 +0000 (RFC 2822)
        "%Y-%m-%d"               # e.g., 2025-02-03 (if only the date is provided)
    ]
    
    for item in AllItemsX:
        # Extract values from item, defaulting to an empty string if not present
        title = item.get("title", "")
        summary = item.get("summary", "")
        link = item.get("link", "")
        published_raw = item.get("published", "")
        
        # Initialize the formatted published date with the raw value as a fallback
        published_formatted = published_raw
        
        # Try parsing the published date using each possible format
        for fmt in possible_formats:
            try:
                parsed_date = datetime.strptime(published_raw, fmt)
                published_formatted = parsed_date.strftime("%Y-%m-%d %H:%M:%S")
                break  # Stop trying once parsing succeeds
            except ValueError:
                continue  # Try the next format if the current one fails
        
        # Append the extracted and formatted data to finalList
        finalList.append([title, summary, link, published_formatted])
    
    return finalList

# # Example usage:
# AllItemsX = [
#     {
#         "title": "First Post",
#         "summary": "This is the summary for the first post.",
#         "link": "http://example.com/1",
#         "published": "2025-02-03T15:30:00Z"
#     },
#     {
#         "title": "Second Post",
#         "summary": "This is the summary for the second post.",
#         "link": "http://example.com/2",
#         "published": "Tue, 03 Feb 2025 15:30:00 +0000"
#     }
# ]

# Create and print the final list
MyTheFinalList = ThefinalList()
print(MyTheFinalList)
# Out:
# [['Musk: Trump med på att skrota USAID', 'Donald Trumps nära rådgivare Elon Musk vill lägga ner biståndsmyndigheten USAID och säger att presidenten är med på beslutet. ”USAID är en kriminell organisation”, dundrar han på sin plattform X där USAID har portats.', 'https://www.dn.se/varlden/musk-trump-med-pa-att-skrota-usaid/', '2025-02-03 09:12:17'], ['Bred nedgång på Stockholmsbörsen', 'Stockholmsbörsen faller brett i den inledande handeln i spåren av president Donald Trumps tullhot. OMXS-index är ned 2,5 procent.', 'https://www.dn.se/ekonomi/bred-nedgang-pa-stockholmsborsen-13/', '2025-02-03 09:09:15'], ['Med uppdrag att stoppa bidragsfusket', 'Nya Utbetalningsmyndigheten har på ett år hittat över 300 misstänkta bidragsbrott genom att samköra myndigheternas system, fall som inte hade upptäckts med tidigare metoder. Nästa steg är att ta fram en modell för att upptäcka fusk kopplat till utlandet, berättar generaldirektören Per Eleblad.', 'https://www.dn.se/ekonomi/med-uppdrag-att-stoppa-bidragsfusket/', '2025-02-03 08:57:07'], ['Europa oroar sig över Trump 2.0 – resten av världen optimistiska', 'BRYSSEL. I Europa betraktas Donald Trump som en fara. Men i stora delar av övriga världen tror man i stället att maktskiftet i USA kan få stopp på kriget i Ukraina, visar en global opinionsmätning.', 'https://www.dn.se/varlden/europa-oroar-sig-over-trump-2-0-resten-av-varlden-optimistiska/', '2025-02-03 08:46:44'], ['Trump rensar hemsidor på ”mångfald” och ”inkludering”', 'Efter president Donald Trumps direktiv rensas amerikanska myndigheters webbplatser på ord som ”mångfald” och ”inkludering”. Uttryck som ”gravida människor” ersätts med ”gravida kvinnor”, rapporterar Washington Post.', 'https://www.dn.se/varlden/trump-rensar-hemsidor-pa-mangfald-och-inkludering/', '2025-02-03 08:46:08'], ['Kalena: Det kanske inte alls var North Dakota du såg', 'Äntligen når Kalena sin 49:e delstat. Men har du sett North Dakota på film eller tv är det stor chans att du såg något helt annat.', 'https://www.dn.se/kultur/kalena-det-kanske-inte-alls-var-north-dakota-du-sag/', '2025-02-03 07:36:13'], ['Oväntad coach i historiska matcher: ”Känns speciellt”', 'När det för första gången ska spelas hockeymatcher i nyrenoverade Avicii arena är det inte ordinarie förbundskapten Sam Hallam som basar över laget. I stället kommer Tre Kronor under veckans landslagsturnering ledas av vikarien Magnus Hävelid.', 'https://www.dn.se/sport/ovantad-coach-i-historiska-matcher-kanns-speciellt/', '2025-02-03 07:18:49'], ['Lamar prisades för diss – Beyoncés album bäst', 'Världsstjärnan Kendrick Lamar prisades två gånger om för sin Drake-diss ”Not like Us”, som tog hem både årets låt och årets inspelning. Årets album blev Beyoncés ”Cowboy Carter” och årets artist Chappell Roan.', 'https://www.dn.se/kultur/lamar-prisades-for-diss-beyonces-album-bast/', '2025-02-03 06:55:34'], ['Ledare: ”Hårda tag” räcker inte mot hedersvåldet', 'Nu är det inte längre tabu att tala om hedersvåld. Men samhället är fortfarande för dåligt på att stoppa det.', 'https://www.dn.se/ledare/harda-tag-racker-inte-mot-hedersvaldet/', '2025-02-03 06:03:55'], ['Var finns största glaciären?', 'Testa dina kunskaper om iskalla ting.', 'https://www.dn.se/quiz/djur-och-natur/is-och-glaciarer/', '2025-02-03 06:00:00'], ['Rättsläkare: Större risk att utomstående skadas', 'När gängen använder militära kulor ökar risken för att utomstående drabbas av skjutvapenvåldet, enligt rättsläkaren Lydia Kahn. – En helmantlad kula stannar inte upp i kroppen. Den fortsätter och riskerar att träffa tredje man, säger hon.', 'https://www.dn.se/sverige/rattslakare-storre-risk-att-utomstaende-skadas/', '2025-02-03 05:51:44'], ['Gängen dödar med försvarets kulor: ”Mer kraftfulla”', 'Kraftfulla helmantlade kulor blev över när militärförband lades ned runt millenniumskiftet. Nu är försvarets gamla ammunition ett återkommande inslag i den grova brottsligheten –\xa0både i gängmord och i ett misstänkt terrorbrott. –\xa0Med tanke på hur ofta vi ...

# %%
# 3) Create a variable that holds the final list
MyTheFinalList = ThefinalList()

#print the final list
print(MyTheFinalList)
print(len(MyTheFinalList))
# Out:
# [['Musk: Trump med på att skrota USAID', 'Donald Trumps nära rådgivare Elon Musk vill lägga ner biståndsmyndigheten USAID och säger att presidenten är med på beslutet. ”USAID är en kriminell organisation”, dundrar han på sin plattform X där USAID har portats.', 'https://www.dn.se/varlden/musk-trump-med-pa-att-skrota-usaid/', '2025-02-03 09:12:17'], ['Bred nedgång på Stockholmsbörsen', 'Stockholmsbörsen faller brett i den inledande handeln i spåren av president Donald Trumps tullhot. OMXS-index är ned 2,5 procent.', 'https://www.dn.se/ekonomi/bred-nedgang-pa-stockholmsborsen-13/', '2025-02-03 09:09:15'], ['Med uppdrag att stoppa bidragsfusket', 'Nya Utbetalningsmyndigheten har på ett år hittat över 300 misstänkta bidragsbrott genom att samköra myndigheternas system, fall som inte hade upptäckts med tidigare metoder. Nästa steg är att ta fram en modell för att upptäcka fusk kopplat till utlandet, berättar generaldirektören Per Eleblad.', 'https://www.dn.se/ekonomi/med-uppdrag-att-stoppa-bidragsfusket/', '2025-02-03 08:57:07'], ['Europa oroar sig över Trump 2.0 – resten av världen optimistiska', 'BRYSSEL. I Europa betraktas Donald Trump som en fara. Men i stora delar av övriga världen tror man i stället att maktskiftet i USA kan få stopp på kriget i Ukraina, visar en global opinionsmätning.', 'https://www.dn.se/varlden/europa-oroar-sig-over-trump-2-0-resten-av-varlden-optimistiska/', '2025-02-03 08:46:44'], ['Trump rensar hemsidor på ”mångfald” och ”inkludering”', 'Efter president Donald Trumps direktiv rensas amerikanska myndigheters webbplatser på ord som ”mångfald” och ”inkludering”. Uttryck som ”gravida människor” ersätts med ”gravida kvinnor”, rapporterar Washington Post.', 'https://www.dn.se/varlden/trump-rensar-hemsidor-pa-mangfald-och-inkludering/', '2025-02-03 08:46:08'], ['Kalena: Det kanske inte alls var North Dakota du såg', 'Äntligen når Kalena sin 49:e delstat. Men har du sett North Dakota på film eller tv är det stor chans att du såg något helt annat.', 'https://www.dn.se/kultur/kalena-det-kanske-inte-alls-var-north-dakota-du-sag/', '2025-02-03 07:36:13'], ['Oväntad coach i historiska matcher: ”Känns speciellt”', 'När det för första gången ska spelas hockeymatcher i nyrenoverade Avicii arena är det inte ordinarie förbundskapten Sam Hallam som basar över laget. I stället kommer Tre Kronor under veckans landslagsturnering ledas av vikarien Magnus Hävelid.', 'https://www.dn.se/sport/ovantad-coach-i-historiska-matcher-kanns-speciellt/', '2025-02-03 07:18:49'], ['Lamar prisades för diss – Beyoncés album bäst', 'Världsstjärnan Kendrick Lamar prisades två gånger om för sin Drake-diss ”Not like Us”, som tog hem både årets låt och årets inspelning. Årets album blev Beyoncés ”Cowboy Carter” och årets artist Chappell Roan.', 'https://www.dn.se/kultur/lamar-prisades-for-diss-beyonces-album-bast/', '2025-02-03 06:55:34'], ['Ledare: ”Hårda tag” räcker inte mot hedersvåldet', 'Nu är det inte längre tabu att tala om hedersvåld. Men samhället är fortfarande för dåligt på att stoppa det.', 'https://www.dn.se/ledare/harda-tag-racker-inte-mot-hedersvaldet/', '2025-02-03 06:03:55'], ['Var finns största glaciären?', 'Testa dina kunskaper om iskalla ting.', 'https://www.dn.se/quiz/djur-och-natur/is-och-glaciarer/', '2025-02-03 06:00:00'], ['Rättsläkare: Större risk att utomstående skadas', 'När gängen använder militära kulor ökar risken för att utomstående drabbas av skjutvapenvåldet, enligt rättsläkaren Lydia Kahn. – En helmantlad kula stannar inte upp i kroppen. Den fortsätter och riskerar att träffa tredje man, säger hon.', 'https://www.dn.se/sverige/rattslakare-storre-risk-att-utomstaende-skadas/', '2025-02-03 05:51:44'], ['Gängen dödar med försvarets kulor: ”Mer kraftfulla”', 'Kraftfulla helmantlade kulor blev över när militärförband lades ned runt millenniumskiftet. Nu är försvarets gamla ammunition ett återkommande inslag i den grova brottsligheten –\xa0både i gängmord och i ett misstänkt terrorbrott. –\xa0Med tanke på hur ofta vi ...
# 240
